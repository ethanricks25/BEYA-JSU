# %% [markdown]
# # 1. Load Dataset

# %%
import pandas as pd

# %%
url = 'patients.csv'
df = pd.read_csv(url)
df.head()
# Out:
#                                      ID  BIRTHDATE  Age DEATHDATE  \
# 0  2de771bf-befb-4d42-944f-d8a9c5242678  8/26/1971   49       NaN
# 1  cf73a172-f375-4305-bfc8-ea8b00f158af  8/27/2008   12       NaN
# 2  8b04c1bf-1c15-4253-aed6-f4955ee75f96  8/16/1949   71       NaN
# 3  b5774f03-07ab-4a16-8f24-9dcf1871e382   9/4/1998   22       NaN
# 4  0b1facbc-f3e5-416a-8cf9-15dc7be16da9  5/29/1962   58       NaN
#
#            SSN        FIRST          LAST MARITAL   RACE    ETHNICITY GENDER  \
# 0  999-10-1119  Adelaida985  Kertzmann286       M  white  nonhispanic      F
# 1  999-10-1145    Benita195    Monahan736     NaN  black  nonhispanic      F
# 2  999-10-1427     Dusty207      Kulas532       M  white  nonhispanic      F
# 3  999-10-1440       Kay203      Bosco882     NaN  white  nonhispanic      F
# 4  999-10-1567   Horacio317    Balderas66       M  white     hispanic      M
#
#                         ADDRESS       CITY          STATE            COUNTY  \
# ...
